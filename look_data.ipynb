# %% [markdown]
# # Manchine learning of stroke CT images
#
# Data set downloaded from
# http://qure.ai/

# %%
import pydicom
import matplotlib.pyplot as plt
import numpy
import gdcm

# %% [markdown]
# ##  Analysis of single file

# %%
name='../data/CQ500CT0 CQ500CT0/Unknown Study/CT Plain/CT000005.dcm'

print("Starting to read " , name)
# Out:
# Starting to read  ../data/CQ500CT0 CQ500CT0/Unknown Study/CT Plain/CT000005.dcm

# %%
dataset = pydicom.dcmread(name)
print("Read from " , name)
print(dataset)
# Out:
# Read from  ../data/CQ500CT0 CQ500CT0/Unknown Study/CT Plain/CT000005.dcm
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: ''
# (0008, 0013) Instance Creation Time              TM: ''
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1521714314.2034086
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# ...

# %%
print(dataset.pixel_array)
# Out:
# [[-2000 -2000 -2000 ... -2000 -2000 -2000]
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]
#  ...
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]]

# %%
plt.imshow(dataset.pixel_array, cmap=plt.cm.bone)
plt.show()

# %%
print(len(dataset.pixel_array))
# Out:
# 512
